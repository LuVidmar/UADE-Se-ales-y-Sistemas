# %% [markdown]
# # TPO 1 - Señales conocidas y sistemas
#
# ### Ejercicio 1
#
# Desarrolle una serie de Scritps en el lunguaje de programación PYTHON, los cuales describan y grafiquen las siguientes funciones (señales conocidas) vistas en CLASE:

# %% [markdown]
# 1. Señal Escalón Unitario en tiempo contínuo.

# %%
# %run 'escalon-unitario-continuo.py' 'no-print'

# %% [markdown]
# 2. Señal Escalón Unitario en tiempo discreto.

# %%
# %run 'escalon-unitario-discreto.py' 'no-print'

# %% [markdown]
# 3. Señal Cajón Unitario en tiempo contínuo.

# %%
# %run 'cajon-unitario-continuo.py' 'no-print'

# %% [markdown]
# 4. Señal Cajón Unitario en tiempo discreto.

# %%
# %run 'cajon-unitario-discreto.py' 'no-print'

# %% [markdown]
# 5. Señal delta de Dirac en tiempo contínuo.

# %%
# %run 'delta-dirac-continuo.py' 'no-print'

# %% [markdown]
# 6. Señal delta de Dirac en tiempo discreto.

# %%
# %run 'delta-dirac-discreto.py' 'no-print'

# %% [markdown]
# 7. Todas las variantes de la Señal Exponencial en tiempo contínuo.

# %%
# %run 'exponencial-real-continuo.py' 'no-print'

# %%
# %run 'exponencial-compleja-continuo.py' 'no-print'

# %% [markdown]
# 8. Todas las variantes de la Señal Exponencial en tiempo discreto.

# %%
# %run 'exponencial-real-discreto.py' 'no-print'

# %%
# %run 'exponencial-compleja-discreto.py' 'no-print'

# %% [markdown]
# ### Ejercicio 2
#
# Desarrolle una serie de Scritps en el lenguaje de programación PYTHON, los cuales describan y grafiquen las siguientes señales:

# %% [markdown]
# 1. Una Señal continua en tiempo contínuo.

# %%
# %run 'senal-continua-tiempo-continuo.py' 'no-print'

# %% [markdown]
# 2. Una Señal continua en tiempo discreto.

# %%
# %run 'senal-continua-tiempo-discreto.py' 'no-print'

# %% [markdown]
# 3. Una Señal continua periódica en tiempo contínuo.

# %%
# %run 'senal-continua-periodica-tiempo-continuo.py' 'no-print'

# %% [markdown]
# 4. Una Señal continua periódica en tiempo discreto.

# %%
# %run 'senal-continua-periodica-tiempo-discreto.py' 'no-print'

# %% [markdown]
# 5. Una Señal continua aperiódica en tiempo contínuo.

# %%
# %run 'senal-continua-aperiodica-tiempo-continuo.py' 'no-print'

# %% [markdown]
# 6. Una Señal continua aperiódica en tiempo discreto.

# %%
# %run 'senal-continua-aperiodica-tiempo-discreto.py' 'no-print'

# %% [markdown]
# 7. Una Señal continua con escalamiento en el tiempo en tiempo contínuo.

# %%
# %run 'senal-continua-escalamiento-tiempo-continuo.py' 'no-print'

# %% [markdown]
# 8. Una Señal continua con escalamiento en el tiempo en tiempo discreto.

# %%
# %run 'senal-continua-escalamiento-tiempo-discreto.py' 'no-print'

# %% [markdown]
# 9. Una Señal continua con desplazamiento en el tiempo en tiempo contínuo.

# %%
# %run 'senal-continua-desplazamiento-tiempo-continuo.py' 'no-print'

# %% [markdown]
# 10. Una Señal continua con desplazamiento en el tiempo en tiempo discreto.

# %%
# %run 'senal-continua-desplazamiento-tiempo-discreto.py' 'no-print'

# %% [markdown]
# 11. Una Señal continua con inversión en el tiempo en tiempo contínuo.

# %%
# %run 'senal-continua-inversion-tiempo-continuo.py' 'no-print'

# %% [markdown]
# 12. Una Señal continua con inversión en el tiempo en tiempo discreto.

# %%
# %run 'senal-continua-inversion-tiempo-discreto.py' 'no-print'

# %% [markdown]
# ### Ejercicio 3
# Desarrolle un de Scritps en el lenguaje de programación PYTHON, el cual describa y grafique una señal de potencia.

# %%
# %run 'senal-potencia.py' 'no-print'

# %% [markdown]
# ### Ejercicio 4
# Desarrolle un de Scritps en el lenguaje de programación PYTHON, el cual describa y grafique una señal de energía.

# %%
# %run 'senal-energia.py' 'no-print'
